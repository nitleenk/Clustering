# %%
import pandas as pd
from sklearn import datasets
from sklearn.cluster import KMeans, AgglomerativeClustering, MeanShift
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Load dataset
iris = datasets.load_iris()
X = iris.data

# Define numbers of clusters
clusters = [3, 4, 5]

# Define preprocessing pipelines
preprocessing_options = {
    'no_preprocessing': None,
    'transform': StandardScaler(),
    'pca': PCA(n_components=2),
    'transform_normalization_pca': Pipeline([
        ('transform_normalization', StandardScaler()),
        ('pca', PCA(n_components=2))
    ]),
}

# Define clustering algorithms
clustering_algorithms = {
    'KMeans': KMeans,
    'Hierarchical': AgglomerativeClustering,
    'MeanShift': MeanShift,
}

# Iterate over each clustering algorithm
for algorithm_name, algorithm_class in clustering_algorithms.items():
    print(f"Clustering Algorithm: {algorithm_name}")

    # Initialize clustering algorithm
    if algorithm_name == 'MeanShift':
        # MeanShift does not require specifying the number of clusters
        algorithm_instance = algorithm_class()
    else:
        algorithm_instance = algorithm_class()

    # Iterate over each preprocessing option
    for preprocessing_name, preprocessor in preprocessing_options.items():
        print(f"Preprocessing: {preprocessing_name}")

        for c in clusters:
            print(f"Number of clusters: {c}")

            if preprocessor is None:
                X_processed = X
            else:
                X_processed = preprocessor.fit_transform(X)

            if algorithm_name != 'MeanShift':
                # Fit clustering algorithm
                algorithm_instance.set_params(n_clusters=c)
                labels = algorithm_instance.fit_predict(X_processed)
            else:
                labels = algorithm_instance.fit_predict(X_processed)
                c = len(set(labels))

            # Calculate evaluation metrics
            silhouette = silhouette_score(X_processed, labels)
            calinski = calinski_harabasz_score(X_processed, labels)
            davies = davies_bouldin_score(X_processed, labels)

            print(f"Silhouette Score: {silhouette}")
            print(f"Calinski-Harabasz Index: {calinski}")
            print(f"Davies-Bouldin Index: {davies}")
            print("-----------------------------")
# Out:
# Clustering Algorithm: KMeans
# Preprocessing: no_preprocessing
# Number of clusters: 3
# Silhouette Score: 0.5511916046195919
# Calinski-Harabasz Index: 561.5937320156642
# Davies-Bouldin Index: 0.6660385791628493
# -----------------------------
# Number of clusters: 4
# Silhouette Score: 0.497295463986756
# Calinski-Harabasz Index: 530.4569389750499
# Davies-Bouldin Index: 0.7794882743881103
# -----------------------------
# Number of clusters: 5
# Silhouette Score: 0.3711254290028659
# Calinski-Harabasz Index: 459.1364715706763
# Davies-Bouldin Index: 0.9080302075136529
# -----------------------------
# Preprocessing: transform
# Number of clusters: 3
# Silhouette Score: 0.4630420362927048
# Calinski-Harabasz Index: 241.42632349435513
# Davies-Bouldin Index: 0.8324162130910141
# -----------------------------
# Number of clusters: 4
# Silhouette Score: 0.41308512352502325
# Calinski-Harabasz Index: 206.07292961986067
# Davies-Bouldin Index: 0.9223321372280167
# -----------------------------
# Number of clusters: 5
# Silhouette Score: 0.36043683829724427
# Calinski-Harabasz Index: 169.18778807563714
# Davies-Bouldin Index: 1.1183482588878504
# -----------------------------
# Preprocessing: pca
# Number of clusters: 3
# Silhouette Score: 0.5976764219547991
# Calinski-Harabasz Index: 693.7084334188472
# Davies-Bouldin Index: 0.5648157434964133
# -----------------------------
# Number of clusters: 4
# Silhouette Score: 0.5591106064519759
# Calinski-Harabasz Index: 718.3740550643821
# Davies-Bouldin Index: 0.6042417593095712
# -----------------------------
# Number of clusters: 5
# Silhouette Score: 0.5515547785513801
# Calinski-Harabasz Index: 685.0267725905677
# Davies-Bouldin Index: 0.6320655624289171
# -----------------------------
# Preprocessing: transform_normalization_pca
# Number of clusters: 3
# Silhouette Score: 0.504997159565594
# Calinski-Harabasz Index: 290.6996751683395
# Davies-Bouldin Index: 0.7145281962589545
# -----------------------------
# Number of clusters: 4
# Silhouette Score: 0.47671484654656354
# Calinski-Harabasz Index: 261.8587579973539
# Davies-Bouldin Index: 0.7422438712972222
# -----------------------------
# Number of clusters: 5
# Silhouette Score: 0.4117668605521148
# Calinski-Harabasz Index: 276.5796685105014
# Davies-Bouldin Index: 0.7856422436762217
# -----------------------------
# Clustering Algorithm: Hierarchical
# Preprocessing: no_preprocessing
# Number of clusters: 3
# Silhouette Score: 0.5543236611296419
# Calinski-Harabasz Index: 558.0580408128307
# Davies-Bouldin Index: 0.6562564540642021
# -----------------------------
# Number of clusters: 4
# Silhouette Score: 0